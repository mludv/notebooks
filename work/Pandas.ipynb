# %%
import sqlalchemy
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
conn = sqlalchemy.create_engine('postgresql://postgres:abc123@localhost:5432/skanova')
koppar = pd.read_sql_query('SELECT * FROM geoanalys.aktiva_koppar where scd_current_row = false', con=conn)

# %%
koppar
# Out:
#              gid   punkt_id naetstn    kc abgtyp har_aktivt_bredband  \
# 0       34674190  131187388     BBK  KC01     A0                True
# 1       34674188  129316950    M/LH           N0               False
# 2       34674243  113000926     ARV  KC01     F0               False
# 3       34674253  100039979      LD           N0               False
# 4       34674310  120779079     GEP  KC01     A0                True
# 5       34674424  117031220      FA           N0               False
# 6       34674626  117176409     RDG  KC01     N0               False
# 7       34674703  112966618    M/DP           N0               False
# 8       34674779  146273772     KÄS           N0               False
# 9       34674832  129621858     KAB           N0               False
# 10      34674923  129219002    M/RG           A0                True
# 11      34674913  121971753    M/SP           N0               False
# 12      34674942  113027883    M/RG           N0               False
# ...

# %%
a = pd.read_sql_query('SELECT * FROM staging.batch_raw INNER JOIN staging.raw ON id = raw_id WHERE batch_id = 942', con=conn)

# %%
dates =
